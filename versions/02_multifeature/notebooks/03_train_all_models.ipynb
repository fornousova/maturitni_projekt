# %%
import os
import sys
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
import pickle
import numpy as np
import pandas as pd

# Cesta ke skriptům
sys.path.append(os.path.abspath("../scripts"))
from utils import Normalizer, create_multifeature_lstm_dataset

# %%
WINDOW_SIZE = 20
BATCH_SIZE = 32
EPOCHS = 50
LEARNING_RATE = 0.001
WEIGHT_DECAY = 1e-5
PATIENCE = 5

results = []  # pro ukládání výsledků

# %%
with open("../data/preprocessed_datasets.pkl", "rb") as f:
    vsechny_datasety = pickle.load(f)

print(f"Načteno {len(vsechny_datasety)} datasetů")
# Out:
# Načteno 18 datasetů

# %%
class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size=64, num_layers=2, dropout=0.3):
        super().__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers,
                            dropout=dropout, batch_first=True)
        self.fc = nn.Linear(hidden_size, 1)

    def forward(self, x):
        out, _ = self.lstm(x)
        out = out[:, -1, :]
        return self.fc(out)

# %%
for data in vsechny_datasety:
    ticker = data["ticker"]
    sektor = data["sector"]

    print(f"Trénuji model pro {ticker} ({sektor})")

    x_train = torch.tensor(data["x_train"], dtype=torch.float32)
    y_train = torch.tensor(data["y_train"], dtype=torch.float32)
    x_val = torch.tensor(data["x_val"], dtype=torch.float32)
    y_val = torch.tensor(data["y_val"], dtype=torch.float32)

    model = LSTMModel(input_size=x_train.shape[2])
    loss_fn = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)

    train_loader = DataLoader(TensorDataset(x_train, y_train), batch_size=BATCH_SIZE, shuffle=True)
    val_loader = DataLoader(TensorDataset(x_val, y_val), batch_size=BATCH_SIZE)

    best_val_loss = float("inf")
    patience_counter = 0

    for epoch in range(EPOCHS):
        model.train()
        train_loss = 0
        for xb, yb in train_loader:
            pred = model(xb).squeeze()
            loss = loss_fn(pred, yb.view(-1))
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            train_loss += loss.item()
        train_loss /= len(train_loader)

        model.eval()
        val_loss = 0
        with torch.no_grad():
            for xb, yb in val_loader:
                pred = model(xb).squeeze()
                loss = loss_fn(pred, yb.view(-1))
                val_loss += loss.item()
        val_loss /= len(val_loader)

        print(f"Epoch {epoch+1}/{EPOCHS} - Train Loss: {train_loss:.4f} - Val Loss: {val_loss:.4f}")

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            patience_counter = 0
            torch.save(model.state_dict(), f"../results/best_model_{ticker}.pth")
        else:
            patience_counter += 1

        if patience_counter >= PATIENCE:
            print(f"Early stopping pro {ticker}")
            break

    results.append({
        "ticker": ticker,
        "sector": sektor,
        "train_loss": round(train_loss, 5),
        "val_loss": round(best_val_loss, 5)
    })
# Out:
# Trénuji model pro NVDA (Technology)
# Epoch 1/50 - Train Loss: 0.0037 - Val Loss: 0.0629
# Epoch 2/50 - Train Loss: 0.0002 - Val Loss: 0.0081
# Epoch 3/50 - Train Loss: 0.0001 - Val Loss: 0.0154
# Epoch 4/50 - Train Loss: 0.0001 - Val Loss: 0.0196
# Epoch 5/50 - Train Loss: 0.0001 - Val Loss: 0.0214
# Epoch 6/50 - Train Loss: 0.0001 - Val Loss: 0.0163
# Epoch 7/50 - Train Loss: 0.0001 - Val Loss: 0.0196
# Early stopping pro NVDA
# Trénuji model pro MSFT (Technology)
# Epoch 1/50 - Train Loss: 0.0268 - Val Loss: 0.0723
# Epoch 2/50 - Train Loss: 0.0013 - Val Loss: 0.0038
# Epoch 3/50 - Train Loss: 0.0007 - Val Loss: 0.0084
# Epoch 4/50 - Train Loss: 0.0006 - Val Loss: 0.0056
# Epoch 5/50 - Train Loss: 0.0006 - Val Loss: 0.0044
# Epoch 6/50 - Train Loss: 0.0006 - Val Loss: 0.0042
# Epoch 7/50 - Train Loss: 0.0005 - Val Loss: 0.0039
# Early stopping pro MSFT
# Trénuji model pro AAPL (Technology)
# Epoch 1/50 - Train Loss: 0.0485 - Val Loss: 0.0125
# Epoch 2/50 - Train Loss: 0.0015 - Val Loss: 0.0014
# Epoch 3/50 - Train Loss: 0.0009 - Val Loss: 0.0038
# Epoch 4/50 - Train Loss: 0.0008 - Val Loss: 0.0037
# Epoch 5/50 - Train Loss: 0.0007 - Val Loss: 0.0028
# Epoch 6/50 - Train Loss: 0.0006 - Val Loss: 0.0057
# Epoch 7/50 - Train Loss: 0.0007 - Val Loss: 0.0038
# Early stopping pro AAPL
# Trénuji model pro META (Communication)
# Epoch 1/50 - Train Loss: 0.0151 - Val Loss: 0.1187
# Epoch 2/50 - Train Loss: 0.0034 - Val Loss: 0.0018
# Epoch 3/50 - Train Loss: 0.0006 - Val Loss: 0.0021
# Epoch 4/50 - Train Loss: 0.0005 - Val Loss: 0.0050
# Epoch 5/50 - Train Loss: 0.0004 - Val Loss: 0.0072
# Epoch 6/50 - Train Loss: 0.0004 - Val Loss: 0.0064
# Epoch 7/50 - Train Loss: 0.0004 - Val Loss: 0.0075
# Early stopping pro META
# Trénuji model pro DIS (Communication)
# Epoch 1/50 - Train Loss: 0.0460 - Val Loss: 0.0019
# Epoch 2/50 - Train Loss: 0.0030 - Val Loss: 0.0010
# Epoch 3/50 - Train Loss: 0.0021 - Val Loss: 0.0010
# Epoch 4/50 - Train Loss: 0.0021 - Val Loss: 0.0008
# Epoch 5/50 - Train Loss: 0.0019 - Val Loss: 0.0008
# Epoch 6/50 - Train Loss: 0.0018 - Val Loss: 0.0007
# Epoch 7/50 - Train Loss: 0.0016 - Val Loss: 0.0007
# Epoch 8/50 - Train Loss: 0.0016 - Val Loss: 0.0007
# Epoch 9/50 - Train Loss: 0.0014 - Val Loss: 0.0006
# Epoch 10/50 - Train Loss: 0.0015 - Val Loss: 0.0007
# Epoch 11/50 - Train Loss: 0.0015 - Val Loss: 0.0006
# Epoch 12/50 - Train Loss: 0.0014 - Val Loss: 0.0006
# Epoch 13/50 - Train Loss: 0.0013 - Val Loss: 0.0005
# Epoch 14/50 - Train Loss: 0.0012 - Val Loss: 0.0007
# Epoch 15/50 - Train Loss: 0.0014 - Val Loss: 0.0005
# Epoch 16/50 - Train Loss: 0.0013 - Val Loss: 0.0005
# Epoch 17/50 - Train Loss: 0.0012 - Val Loss: 0.0006
# Epoch 18/50 - Train Loss: 0.0012 - Val Loss: 0.0005
# Epoch 19/50 - Train Loss: 0.0012 - Val Loss: 0.0005
# Epoch 20/50 - Train Loss: 0.0013 - Val Loss: 0.0005
# Epoch 21/50 - Train Loss: 0.0012 - Val Loss: 0.0005
# Epoch 22/50 - Train Loss: 0.0012 - Val Loss: 0.0004
# Epoch 23/50 - Train Loss: 0.0012 - Val Loss: 0.0004
# Epoch 24/50 - Train Loss: 0.0011 - Val Loss: 0.0005
# Epoch 25/50 - Train Loss: 0.0012 - Val Loss: 0.0004
# Epoch 26/50 - Train Loss: 0.0011 - Val Loss: 0.0005
# Epoch 27/50 - Train Loss: 0.0011 - Val Loss: 0.0004
# Epoch 28/50 - Train Loss: 0.0011 - Val Loss: 0.0004
# Epoch 29/50 - Train Loss: 0.0010 - Val Loss: 0.0004
# Epoch 30/50 - Train Loss: 0.0010 - Val Loss: 0.0004
# Epoch 31/50 - Train Loss: 0.0010 - Val Loss: 0.0004
# Epoch 32/50 - Train Loss: 0.0010 - Val Loss: 0.0004
# Epoch 33/50 - Train Loss: 0.0011 - Val Loss: 0.0004
# Epoch 34/50 - Train Loss: 0.0009 - Val Loss: 0.0004
# Epoch 35/50 - Train Loss: 0.0009 - Val Loss: 0.0003
# Epoch 36/50 - Train Loss: 0.0010 - Val Loss: 0.0004
# Epoch 37/50 - Train Loss: 0.0009 - Val Loss: 0.0003
# Epoch 38/50 - Train Loss: 0.0010 - Val Loss: 0.0005
# Epoch 39/50 - Train Loss: 0.0009 - Val Loss: 0.0003
# Epoch 40/50 - Train Loss: 0.0009 - Val Loss: 0.0003
# Epoch 41/50 - Train Loss: 0.0010 - Val Loss: 0.0004
# Epoch 42/50 - Train Loss: 0.0010 - Val Loss: 0.0004
# Epoch 43/50 - Train Loss: 0.0009 - Val Loss: 0.0003
# Epoch 44/50 - Train Loss: 0.0010 - Val Loss: 0.0004
# Epoch 45/50 - Train Loss: 0.0009 - Val Loss: 0.0003
# Epoch 46/50 - Train Loss: 0.0009 - Val Loss: 0.0004
# Epoch 47/50 - Train Loss: 0.0008 - Val Loss: 0.0004
# Epoch 48/50 - Train Loss: 0.0010 - Val Loss: 0.0003
# Epoch 49/50 - Train Loss: 0.0008 - Val Loss: 0.0003
# Epoch 50/50 - Train Loss: 0.0009 - Val Loss: 0.0003
# Trénuji model pro GOOGL (Communication)
# Epoch 1/50 - Train Loss: 0.0282 - Val Loss: 0.0483
# Epoch 2/50 - Train Loss: 0.0023 - Val Loss: 0.0025
# Epoch 3/50 - Train Loss: 0.0010 - Val Loss: 0.0037
# Epoch 4/50 - Train Loss: 0.0007 - Val Loss: 0.0046
# Epoch 5/50 - Train Loss: 0.0007 - Val Loss: 0.0041
# Epoch 6/50 - Train Loss: 0.0007 - Val Loss: 0.0054
# Epoch 7/50 - Train Loss: 0.0007 - Val Loss: 0.0037
# Early stopping pro GOOGL
# Trénuji model pro BAC (Finance)
# Epoch 1/50 - Train Loss: 0.0412 - Val Loss: 0.0039
# Epoch 2/50 - Train Loss: 0.0024 - Val Loss: 0.0018
# Epoch 3/50 - Train Loss: 0.0020 - Val Loss: 0.0015
# Epoch 4/50 - Train Loss: 0.0018 - Val Loss: 0.0018
# Epoch 5/50 - Train Loss: 0.0017 - Val Loss: 0.0017
# Epoch 6/50 - Train Loss: 0.0016 - Val Loss: 0.0012
# Epoch 7/50 - Train Loss: 0.0015 - Val Loss: 0.0013
# Epoch 8/50 - Train Loss: 0.0015 - Val Loss: 0.0013
# Epoch 9/50 - Train Loss: 0.0017 - Val Loss: 0.0030
# Epoch 10/50 - Train Loss: 0.0016 - Val Loss: 0.0011
# Epoch 11/50 - Train Loss: 0.0013 - Val Loss: 0.0012
# Epoch 12/50 - Train Loss: 0.0013 - Val Loss: 0.0010
# Epoch 13/50 - Train Loss: 0.0012 - Val Loss: 0.0012
# Epoch 14/50 - Train Loss: 0.0012 - Val Loss: 0.0015
# Epoch 15/50 - Train Loss: 0.0012 - Val Loss: 0.0011
# Epoch 16/50 - Train Loss: 0.0011 - Val Loss: 0.0009
# Epoch 17/50 - Train Loss: 0.0011 - Val Loss: 0.0009
# Epoch 18/50 - Train Loss: 0.0012 - Val Loss: 0.0009
# Epoch 19/50 - Train Loss: 0.0011 - Val Loss: 0.0010
# Epoch 20/50 - Train Loss: 0.0010 - Val Loss: 0.0010
# Epoch 21/50 - Train Loss: 0.0010 - Val Loss: 0.0009
# Epoch 22/50 - Train Loss: 0.0010 - Val Loss: 0.0008
# Epoch 23/50 - Train Loss: 0.0011 - Val Loss: 0.0018
# Epoch 24/50 - Train Loss: 0.0011 - Val Loss: 0.0024
# Epoch 25/50 - Train Loss: 0.0011 - Val Loss: 0.0020
# Epoch 26/50 - Train Loss: 0.0009 - Val Loss: 0.0015
# Epoch 27/50 - Train Loss: 0.0010 - Val Loss: 0.0010
# Early stopping pro BAC
# Trénuji model pro JPM (Finance)
# Epoch 1/50 - Train Loss: 0.0131 - Val Loss: 0.0137
# Epoch 2/50 - Train Loss: 0.0011 - Val Loss: 0.0061
# Epoch 3/50 - Train Loss: 0.0006 - Val Loss: 0.0015
# Epoch 4/50 - Train Loss: 0.0005 - Val Loss: 0.0028
# Epoch 5/50 - Train Loss: 0.0005 - Val Loss: 0.0038
# Epoch 6/50 - Train Loss: 0.0004 - Val Loss: 0.0042
# Epoch 7/50 - Train Loss: 0.0004 - Val Loss: 0.0061
# Epoch 8/50 - Train Loss: 0.0004 - Val Loss: 0.0055
# Early stopping pro JPM
# Trénuji model pro GS (Finance)
# Epoch 1/50 - Train Loss: 0.0246 - Val Loss: 0.0772
# Epoch 2/50 - Train Loss: 0.0027 - Val Loss: 0.0017
# Epoch 3/50 - Train Loss: 0.0009 - Val Loss: 0.0016
# Epoch 4/50 - Train Loss: 0.0007 - Val Loss: 0.0015
# Epoch 5/50 - Train Loss: 0.0006 - Val Loss: 0.0033
# Epoch 6/50 - Train Loss: 0.0006 - Val Loss: 0.0050
# Epoch 7/50 - Train Loss: 0.0005 - Val Loss: 0.0085
# Epoch 8/50 - Train Loss: 0.0005 - Val Loss: 0.0087
# Epoch 9/50 - Train Loss: 0.0005 - Val Loss: 0.0052
# Early stopping pro GS
# Trénuji model pro PG (Consumer)
# Epoch 1/50 - Train Loss: 0.0678 - Val Loss: 0.0161
# Epoch 2/50 - Train Loss: 0.0031 - Val Loss: 0.0007
# Epoch 3/50 - Train Loss: 0.0013 - Val Loss: 0.0009
# Epoch 4/50 - Train Loss: 0.0011 - Val Loss: 0.0024
# Epoch 5/50 - Train Loss: 0.0010 - Val Loss: 0.0030
# Epoch 6/50 - Train Loss: 0.0010 - Val Loss: 0.0015
# Epoch 7/50 - Train Loss: 0.0009 - Val Loss: 0.0014
# Early stopping pro PG
# Trénuji model pro WMT (Consumer)
# Epoch 1/50 - Train Loss: 0.0163 - Val Loss: 0.1022
# Epoch 2/50 - Train Loss: 0.0020 - Val Loss: 0.0016
# Epoch 3/50 - Train Loss: 0.0004 - Val Loss: 0.0042
# Epoch 4/50 - Train Loss: 0.0004 - Val Loss: 0.0083
# Epoch 5/50 - Train Loss: 0.0003 - Val Loss: 0.0069
# Epoch 6/50 - Train Loss: 0.0003 - Val Loss: 0.0086
# Epoch 7/50 - Train Loss: 0.0003 - Val Loss: 0.0084
# Early stopping pro WMT
# Trénuji model pro KO (Consumer)
# Epoch 1/50 - Train Loss: 0.0370 - Val Loss: 0.0024
# Epoch 2/50 - Train Loss: 0.0024 - Val Loss: 0.0014
# Epoch 3/50 - Train Loss: 0.0014 - Val Loss: 0.0032
# Epoch 4/50 - Train Loss: 0.0013 - Val Loss: 0.0021
# Epoch 5/50 - Train Loss: 0.0012 - Val Loss: 0.0026
# Epoch 6/50 - Train Loss: 0.0011 - Val Loss: 0.0028
# Epoch 7/50 - Train Loss: 0.0011 - Val Loss: 0.0019
# Early stopping pro KO
# Trénuji model pro NEE (Energy)
# Epoch 1/50 - Train Loss: 0.0897 - Val Loss: 0.0053
# Epoch 2/50 - Train Loss: 0.0038 - Val Loss: 0.0019
# Epoch 3/50 - Train Loss: 0.0025 - Val Loss: 0.0017
# Epoch 4/50 - Train Loss: 0.0022 - Val Loss: 0.0015
# Epoch 5/50 - Train Loss: 0.0023 - Val Loss: 0.0019
# Epoch 6/50 - Train Loss: 0.0021 - Val Loss: 0.0014
# Epoch 7/50 - Train Loss: 0.0020 - Val Loss: 0.0015
# Epoch 8/50 - Train Loss: 0.0019 - Val Loss: 0.0026
# Epoch 9/50 - Train Loss: 0.0018 - Val Loss: 0.0015
# Epoch 10/50 - Train Loss: 0.0017 - Val Loss: 0.0015
# Epoch 11/50 - Train Loss: 0.0016 - Val Loss: 0.0016
# Early stopping pro NEE
# Trénuji model pro CVX (Energy)
# Epoch 1/50 - Train Loss: 0.0451 - Val Loss: 0.0086
# Epoch 2/50 - Train Loss: 0.0029 - Val Loss: 0.0031
# Epoch 3/50 - Train Loss: 0.0019 - Val Loss: 0.0015
# Epoch 4/50 - Train Loss: 0.0015 - Val Loss: 0.0025
# Epoch 5/50 - Train Loss: 0.0015 - Val Loss: 0.0028
# Epoch 6/50 - Train Loss: 0.0015 - Val Loss: 0.0019
# Epoch 7/50 - Train Loss: 0.0013 - Val Loss: 0.0015
# Epoch 8/50 - Train Loss: 0.0013 - Val Loss: 0.0013
# Epoch 9/50 - Train Loss: 0.0012 - Val Loss: 0.0012
# Epoch 10/50 - Train Loss: 0.0012 - Val Loss: 0.0012
# Epoch 11/50 - Train Loss: 0.0012 - Val Loss: 0.0011
# Epoch 12/50 - Train Loss: 0.0011 - Val Loss: 0.0011
# Epoch 13/50 - Train Loss: 0.0011 - Val Loss: 0.0011
# Epoch 14/50 - Train Loss: 0.0010 - Val Loss: 0.0012
# Epoch 15/50 - Train Loss: 0.0009 - Val Loss: 0.0010
# Epoch 16/50 - Train Loss: 0.0009 - Val Loss: 0.0011
# Epoch 17/50 - Train Loss: 0.0009 - Val Loss: 0.0012
# Epoch 18/50 - Train Loss: 0.0010 - Val Loss: 0.0009
# Epoch 19/50 - Train Loss: 0.0009 - Val Loss: 0.0009
# Epoch 20/50 - Train Loss: 0.0009 - Val Loss: 0.0014
# Epoch 21/50 - Train Loss: 0.0009 - Val Loss: 0.0011
# Epoch 22/50 - Train Loss: 0.0009 - Val Loss: 0.0009
# Epoch 23/50 - Train Loss: 0.0008 - Val Loss: 0.0013
# Epoch 24/50 - Train Loss: 0.0009 - Val Loss: 0.0015
# Epoch 25/50 - Train Loss: 0.0010 - Val Loss: 0.0009
# Epoch 26/50 - Train Loss: 0.0009 - Val Loss: 0.0008
# Epoch 27/50 - Train Loss: 0.0008 - Val Loss: 0.0008
# Epoch 28/50 - Train Loss: 0.0009 - Val Loss: 0.0015
# Epoch 29/50 - Train Loss: 0.0008 - Val Loss: 0.0008
# Epoch 30/50 - Train Loss: 0.0008 - Val Loss: 0.0007
# Epoch 31/50 - Train Loss: 0.0007 - Val Loss: 0.0011
# Epoch 32/50 - Train Loss: 0.0008 - Val Loss: 0.0008
# Epoch 33/50 - Train Loss: 0.0008 - Val Loss: 0.0008
# Epoch 34/50 - Train Loss: 0.0007 - Val Loss: 0.0007
# Epoch 35/50 - Train Loss: 0.0008 - Val Loss: 0.0008
# Epoch 36/50 - Train Loss: 0.0008 - Val Loss: 0.0007
# Epoch 37/50 - Train Loss: 0.0007 - Val Loss: 0.0011
# Epoch 38/50 - Train Loss: 0.0009 - Val Loss: 0.0007
# Epoch 39/50 - Train Loss: 0.0007 - Val Loss: 0.0007
# Epoch 40/50 - Train Loss: 0.0007 - Val Loss: 0.0009
# Epoch 41/50 - Train Loss: 0.0007 - Val Loss: 0.0007
# Early stopping pro CVX
# Trénuji model pro XOM (Energy)
# Epoch 1/50 - Train Loss: 0.0397 - Val Loss: 0.0056
# Epoch 2/50 - Train Loss: 0.0018 - Val Loss: 0.0010
# Epoch 3/50 - Train Loss: 0.0010 - Val Loss: 0.0009
# Epoch 4/50 - Train Loss: 0.0010 - Val Loss: 0.0012
# Epoch 5/50 - Train Loss: 0.0009 - Val Loss: 0.0009
# Epoch 6/50 - Train Loss: 0.0009 - Val Loss: 0.0009
# Epoch 7/50 - Train Loss: 0.0008 - Val Loss: 0.0013
# Epoch 8/50 - Train Loss: 0.0009 - Val Loss: 0.0010
# Early stopping pro XOM
# Trénuji model pro CAT (Industrial)
# Epoch 1/50 - Train Loss: 0.0173 - Val Loss: 0.0496
# Epoch 2/50 - Train Loss: 0.0012 - Val Loss: 0.0052
# Epoch 3/50 - Train Loss: 0.0007 - Val Loss: 0.0016
# Epoch 4/50 - Train Loss: 0.0006 - Val Loss: 0.0034
# Epoch 5/50 - Train Loss: 0.0006 - Val Loss: 0.0015
# Epoch 6/50 - Train Loss: 0.0005 - Val Loss: 0.0031
# Epoch 7/50 - Train Loss: 0.0005 - Val Loss: 0.0035
# Epoch 8/50 - Train Loss: 0.0006 - Val Loss: 0.0015
# Epoch 9/50 - Train Loss: 0.0006 - Val Loss: 0.0028
# Epoch 10/50 - Train Loss: 0.0005 - Val Loss: 0.0029
# Early stopping pro CAT
# Trénuji model pro BA (Industrial)
# Epoch 1/50 - Train Loss: 0.0661 - Val Loss: 0.0039
# Epoch 2/50 - Train Loss: 0.0035 - Val Loss: 0.0012
# Epoch 3/50 - Train Loss: 0.0033 - Val Loss: 0.0017
# Epoch 4/50 - Train Loss: 0.0028 - Val Loss: 0.0008
# Epoch 5/50 - Train Loss: 0.0021 - Val Loss: 0.0007
# Epoch 6/50 - Train Loss: 0.0021 - Val Loss: 0.0007
# Epoch 7/50 - Train Loss: 0.0020 - Val Loss: 0.0006
# Epoch 8/50 - Train Loss: 0.0019 - Val Loss: 0.0006
# Epoch 9/50 - Train Loss: 0.0019 - Val Loss: 0.0006
# Epoch 10/50 - Train Loss: 0.0017 - Val Loss: 0.0005
# Epoch 11/50 - Train Loss: 0.0018 - Val Loss: 0.0006
# Epoch 12/50 - Train Loss: 0.0017 - Val Loss: 0.0005
# Epoch 13/50 - Train Loss: 0.0016 - Val Loss: 0.0005
# Epoch 14/50 - Train Loss: 0.0016 - Val Loss: 0.0006
# Epoch 15/50 - Train Loss: 0.0015 - Val Loss: 0.0006
# Epoch 16/50 - Train Loss: 0.0014 - Val Loss: 0.0005
# Epoch 17/50 - Train Loss: 0.0013 - Val Loss: 0.0005
# Epoch 18/50 - Train Loss: 0.0014 - Val Loss: 0.0005
# Epoch 19/50 - Train Loss: 0.0015 - Val Loss: 0.0004
# Epoch 20/50 - Train Loss: 0.0014 - Val Loss: 0.0004
# Epoch 21/50 - Train Loss: 0.0013 - Val Loss: 0.0004
# Epoch 22/50 - Train Loss: 0.0012 - Val Loss: 0.0004
# Epoch 23/50 - Train Loss: 0.0013 - Val Loss: 0.0004
# Epoch 24/50 - Train Loss: 0.0012 - Val Loss: 0.0004
# Epoch 25/50 - Train Loss: 0.0012 - Val Loss: 0.0004
# Epoch 26/50 - Train Loss: 0.0012 - Val Loss: 0.0004
# Epoch 27/50 - Train Loss: 0.0012 - Val Loss: 0.0004
# Epoch 28/50 - Train Loss: 0.0014 - Val Loss: 0.0004
# Epoch 29/50 - Train Loss: 0.0012 - Val Loss: 0.0005
# Epoch 30/50 - Train Loss: 0.0012 - Val Loss: 0.0004
# Epoch 31/50 - Train Loss: 0.0012 - Val Loss: 0.0004
# Epoch 32/50 - Train Loss: 0.0011 - Val Loss: 0.0004
# Epoch 33/50 - Train Loss: 0.0011 - Val Loss: 0.0004
# Epoch 34/50 - Train Loss: 0.0011 - Val Loss: 0.0003
# Epoch 35/50 - Train Loss: 0.0012 - Val Loss: 0.0003
# Epoch 36/50 - Train Loss: 0.0011 - Val Loss: 0.0003
# Epoch 37/50 - Train Loss: 0.0010 - Val Loss: 0.0003
# Epoch 38/50 - Train Loss: 0.0011 - Val Loss: 0.0004
# Epoch 39/50 - Train Loss: 0.0010 - Val Loss: 0.0003
# Epoch 40/50 - Train Loss: 0.0010 - Val Loss: 0.0003
# Epoch 41/50 - Train Loss: 0.0009 - Val Loss: 0.0003
# Epoch 42/50 - Train Loss: 0.0010 - Val Loss: 0.0004
# Epoch 43/50 - Train Loss: 0.0010 - Val Loss: 0.0003
# Epoch 44/50 - Train Loss: 0.0009 - Val Loss: 0.0004
# Epoch 45/50 - Train Loss: 0.0009 - Val Loss: 0.0004
# Epoch 46/50 - Train Loss: 0.0012 - Val Loss: 0.0004
# Epoch 47/50 - Train Loss: 0.0010 - Val Loss: 0.0004
# Epoch 48/50 - Train Loss: 0.0009 - Val Loss: 0.0003
# Epoch 49/50 - Train Loss: 0.0009 - Val Loss: 0.0003
# Epoch 50/50 - Train Loss: 0.0009 - Val Loss: 0.0003
# Trénuji model pro UNP (Industrial)
# Epoch 1/50 - Train Loss: 0.0872 - Val Loss: 0.0177
# Epoch 2/50 - Train Loss: 0.0069 - Val Loss: 0.0015
# Epoch 3/50 - Train Loss: 0.0024 - Val Loss: 0.0019
# Epoch 4/50 - Train Loss: 0.0021 - Val Loss: 0.0016
# Epoch 5/50 - Train Loss: 0.0019 - Val Loss: 0.0013
# Epoch 6/50 - Train Loss: 0.0019 - Val Loss: 0.0019
# Epoch 7/50 - Train Loss: 0.0018 - Val Loss: 0.0016
# Epoch 8/50 - Train Loss: 0.0017 - Val Loss: 0.0033
# Epoch 9/50 - Train Loss: 0.0019 - Val Loss: 0.0015
# Epoch 10/50 - Train Loss: 0.0016 - Val Loss: 0.0014
# Early stopping pro UNP

# %%
results_df = pd.DataFrame(results)
results_df.to_csv("../results/all_model_results.csv", index=False)
print("Výsledky uloženy do all_model_results.csv")
results_df.head()
# Out:
# Výsledky uloženy do all_model_results.csv
#   ticker         sector  train_loss  val_loss
# 0   NVDA     Technology     0.00011   0.00807
# 1   MSFT     Technology     0.00054   0.00383
# 2   AAPL     Technology     0.00067   0.00144
# 3   META  Communication     0.00039   0.00181
# 4    DIS  Communication     0.00089   0.00029
